# %% [markdown]
# # 5, SQL _ meta data of the database _ interact with the data and the table structure
# ----
# ## OUTLINE:
# 1. sqlite_master:
# - Check the name of all tables
# - Check the properties of a table
# 2. Interact with tables within the database:
# - Create a copy of a table:
# - Add new columns to a table: ALTER TABLE tab_name ADD
# - Update the values of a row: UPDATE tab_name Set col = val WHERE
# - Rename a table
# - Find the average number associated with each value within a category: GROUP BY
# - Filter output: HAVING vs WHERE
# - Logical operators: BETWEEN AND
# - Truncate a table: TRUNCATE TABLE
# - Drop a table: DROP TABLE

# %%
# %load_ext sql
#the magic command to load the SQL extension

# %sql sqlite:///testdatabase.db
#connect and create a db on your computer if it does not exist"

# %% [markdown]
# ### a. Check name of all tables within the database:
# ```sql
# SELECT name
# FROM sqlite_master
# WHERE type = 'table'
# ```
# - `sqlite_master` is the table that contains the metadata of a particular sqlite database.

# %%
# %%sql
# SELECT name
# FROM sqlite_master
# WHERE type = 'table'
# Out:
#  * sqlite:///testdatabase.db
# Done.
# [('population',),
#  ('Indian_female_2021',),
#  ('Indian_male_2021',),
#  ('Indian_all_2021',)]

# %% [markdown]
# ### b. Check the property of a particular within the database:
# ```sql
# SELECT *
# FROM sqlite_master
# WHERE type = 'table'
# AND name = 'table_name';
# ```

# %%
# %%sql
# SELECT *
# FROM sqlite_master
# WHERE type = 'table'
# AND name = 'population'
# Out:
#  * sqlite:///testdatabase.db
# Done.
# [('table', 'population', 'population', 2, 'CREATE TABLE population (\n    YEAR INT NOT NULL,\n    ETHNIC_GROUP VARCHAR(30) NOT NULL,\n    GENDER VARCHAR(30) NOT NULL,\n    AGE VARCHAR(30) NOT NULL,\n    VALUE INT,\n    PRIMARY KEY (YEAR, ETHNIC_GROUP, GENDER, AGE, VALUE)\n)')]

# %% [markdown]
# - In sqlite3, it is IMPOSSIBLE to DIRECTLY change the datatype of a column.

# %% [markdown]
# ### c. Create a copy of the table:

# %%
# %%sql
# CREATE TABLE copy_pop AS
#     SELECT *
#     FROM population
# Out:
#  * sqlite:///testdatabase.db
# Done.
# []

# %% [markdown]
# ### d. Add new columns:
# - Create a new column to encode the Gender variable: 1 for female and 0 for male.

# %% [markdown]
# - Add new column:
# ```sql
# %%sql
# ALTER TABLE table_name
# ADD col1 datatype,
# col2 datatype,...
# ```

# %%
# %%sql
# ALTER TABLE copy_pop
# ADD GENDER_CODE INT
# Out:
#  * sqlite:///testdatabase.db
# Done.
# []

# %% [markdown]
# ### e. Update the value of a row:
# ```sql
# UPDATE table_name
# SET col = value
# WHERE <condition>
# ```

# %%
# %%sql
# UPDATE copy_pop
# SET GENDER_CODE = 0
# WHERE GENDER = 'Male'
# Out:
#  * sqlite:///testdatabase.db
# 4375 rows affected.
# []

# %%
# %%sql
# UPDATE copy_pop
# SET GENDER_CODE = 1
# WHERE GENDER = 'Female'
# Out:
#  * sqlite:///testdatabase.db
# 4375 rows affected.
# []

# %% [markdown]
# - Delete rows associated to All genders value

# %%
# %%sql
# DELETE FROM copy_pop
# WHERE GENDER LIKE 'All%'
# Out:
#  * sqlite:///testdatabase.db
# 4375 rows affected.
# []

# %% [markdown]
# - Delete rows associated to All ages value

# %%
# %%sql
# DELETE FROM copy_pop
# WHERE AGE LIKE 'All%'
# Out:
#  * sqlite:///testdatabase.db
# 350 rows affected.
# []

# %%
# %%sql
# SELECT *
# FROM copy_pop
# Out:
#  * sqlite:///testdatabase.db
# Done.
# [(2022, 'All ethnicity', 'Male', '0 - 4 Years', 86509, 0),
#  (2022, 'All ethnicity', 'Male', '5 - 9 Years', 93894, 0),
#  (2022, 'All ethnicity', 'Male', '10 - 14 Years', 92341, 0),
#  (2022, 'All ethnicity', 'Male', '15 - 19 Years', 94952, 0),
#  (2022, 'All ethnicity', 'Male', '20 - 24 Years', 112471, 0),
#  (2022, 'All ethnicity', 'Male', '25 - 29 Years', 125777, 0),
#  (2022, 'All ethnicity', 'Male', '30 - 34 Years', 129526, 0),
#  (2022, 'All ethnicity', 'Male', '35 - 39 Years', 110784, 0),
#  (2022, 'All ethnicity', 'Male', '40 - 44 Years', 110672, 0),
#  (2022, 'All ethnicity', 'Male', '45 - 49 Years', 116042, 0),
#  (2022, 'All ethnicity', 'Male', '50 - 54 Years', 118751, 0),
#  (2022, 'All ethnicity', 'Male', '55 - 59 Years', 132922, 0),
#  (2022, 'All ethnicity', 'Male', '60 - 64 Years', 134203, 0),
#  (2022, 'All ethnicity', 'Male', '65 - 69 Years', 116045, 0),
#  (2022, 'All ethnicity', 'Male', '70 - 74 Years', 86330, 0),
#  (2022, 'All ethnicity', 'Male', '75 - 79 Years', 46152, 0),
#  (2022, 'All ethnicity', 'Male', '80 - 84 Years', 29905, 0),
#  (2022, 'All ethnicity', 'Male', '85 - 89 Years', 13804, 0),
#  (2022, 'All ethnicity', 'Male', '65 Years & Over', 299031, 0),
#  (2022, 'All ethnicity', 'Male', '70 Years & Over', 182986, 0),
#  (2022, 'All ethnicity', 'Male', '75 Years & Over', 96656, 0),
#  (2022, 'All ethnicity', 'Male', '80 Years & Over', 50504, 0),
#  (2022, 'All ethnicity', 'Male', '85 Years & Over', 20599, 0),
#  (2022, 'All ethnicity', 'Male', '90 Years & Over', 6795, 0),
#  (2022, 'All ethnicity', 'Female', '0 - 4 Years', 82692, 1),
#  (2022, 'All ethnicity', 'Female', '5 - 9 Years', 88622, 1),
#  (2022, 'All ethnicity', 'Female', '10 - 14 Years', 87560, 1),
#  (2022, 'All ethnicity', 'Female', '15 - 19 Years', 90008, 1),
#  (2022, 'All ethnicity', 'Female', '20 - 24 Years', 103193, 1),
#  (2022, 'All ethnicity', 'Female', '25 - 29 Years', 116266, 1),
#  (2022, 'All ethnicity', 'Female', '30 - 34 Years', 124474, 1),
#  (2022, 'All ethnicity', 'Female', '35 - 39 Years', 111321, 1),
#  (2022, 'All ethnicity', 'Female', '40 - 44 Years', 115628, 1),
#  (2022, 'All ethnicity', 'Female', '45 - 49 Years', 123220, 1),
#  (2022, 'All ethnicity', 'Female', '50 - 54 Years', 125976, 1),
#  (2022, 'All ethnicity', 'Female', '55 - 59 Years', 136050, 1),
#  (2022, 'All ethnicity', 'Female', '60 - 64 Years', 136682, 1),
#  (2022, 'All ethnicity', 'Female', '65 - 69 Years', 121312, 1),
#  (2022, 'All ethnicity', 'Female', '70 - 74 Years', 95531, 1),
#  (2022, 'All ethnicity', 'Female', '75 - 79 Years', 55889, 1),
#  (2022, 'All ethnicity', 'Female', '80 - 84 Years', 42615, 1),
#  (2022, 'All ethnicity', 'Female', '85 - 89 Years', 23136, 1),
#  (2022, 'All ethnicity', 'Female', '65 Years & Over', 354182, 1),
#  (2022, 'All ethnicity', 'Female', '70 Years & Over', 232870, 1),
#  (2022, 'All ethnicity', 'Female', '75 Years & Over', 137339, 1),
#  (2022, 'All ethnicity', 'Female', '80 Years & Over', 81450, 1),
#  (2022, 'All ethnicity', 'Female', '85 Years & Over', 38835, 1),
#  (2022, 'All ethnicity', 'Female', '90 Years & Over', 15699, 1),
#  (2022, 'Malays', 'Male', '0 - 4 Years', 20529, 0),
#  (2022, 'Malays', 'Male', '5 - 9 Years', 17772, 0),
#  (2022, 'Malays', 'Male', '10 - 14 Years', 15833, 0),
#  (2022, 'Malays', 'Male', '15 - 19 Years', 17458, 0),
#  (2022, 'Malays', 'Male', '20 - 24 Years', 21614, 0),
#  (2022, 'Malays', 'Male', '25 - 29 Years', 23981, 0),
#  (2022, 'Malays', 'Male', '30 - 34 Years', 24099, 0),
#  (2022, 'Malays', 'Male', '35 - 39 Years', 19388, 0),
#  (2022, 'Malays', 'Male', '40 - 44 Years', 15065, 0),
#  (2022, 'Malays', 'Male', '45 - 49 Years', 13914, 0),
#  (2022, 'Malays', 'Male', '50 - 54 Years', 15219, 0),
#  (2022, 'Malays', 'Male', '55 - 59 Years', 19750, 0),
#  (2022, 'Malays', 'Male', '60 - 64 Years', 18418, 0),
#  (2022, 'Malays', 'Male', '65 - 69 Years', 13125, 0),
#  (2022, 'Malays', 'Male', '70 - 74 Years', 7795, 0),
#  (2022, 'Malays', 'Male', '75 - 79 Years', 3647, 0),
#  (2022, 'Malays', 'Male', '80 - 84 Years', 2067, 0),
#  (2022, 'Malays', 'Male', '85 - 89 Years', 1106, 0),
#  (2022, 'Malays', 'Male', '65 Years & Over', 28209, 0),
#  (2022, 'Malays', 'Male', '70 Years & Over', 15084, 0),
#  (2022, 'Malays', 'Male', '75 Years & Over', 7289, 0),
#  (2022, 'Malays', 'Male', '80 Years & Over', 3642, 0),
#  (2022, 'Malays', 'Male', '85 Years & Over', 1575, 0),
#  (2022, 'Malays', 'Male', '90 Years & Over', 469, 0),
#  (2022, 'Malays', 'Female', '0 - 4 Years', 19603, 1),
#  (2022, 'Malays', 'Female', '5 - 9 Years', 16790, 1),
#  (2022, 'Malays', 'Female', '10 - 14 Years', 15085, 1),
#  (2022, 'Malays', 'Female', '15 - 19 Years', 16464, 1),
#  (2022, 'Malays', 'Female', '20 - 24 Years', 19964, 1),
#  (2022, 'Malays', 'Female', '25 - 29 Years', 22331, 1),
#  (2022, 'Malays', 'Female', '30 - 34 Years', 22876, 1),
#  (2022, 'Malays', 'Female', '35 - 39 Years', 18627, 1),
#  (2022, 'Malays', 'Female', '40 - 44 Years', 14578, 1),
#  (2022, 'Malays', 'Female', '45 - 49 Years', 13606, 1),
#  (2022, 'Malays', 'Female', '50 - 54 Years', 15547, 1),
#  (2022, 'Malays', 'Female', '55 - 59 Years', 20246, 1),
#  (2022, 'Malays', 'Female', '60 - 64 Years', 18477, 1),
#  (2022, 'Malays', 'Female', '65 - 69 Years', 13852, 1),
#  (2022, 'Malays', 'Female', '70 - 74 Years', 9147, 1),
#  (2022, 'Malays', 'Female', '75 - 79 Years', 4510, 1),
#  (2022, 'Malays', 'Female', '80 - 84 Years', 2954, 1),
#  (2022, 'Malays', 'Female', '85 - 89 Years', 1781, 1),
#  (2022, 'Malays', 'Female', '65 Years & Over', 33011, 1),
#  (2022, 'Malays', 'Female', '70 Years & Over', 19159, 1),
#  (2022, 'Malays', 'Female', '75 Years & Over', 10012, 1),
#  (2022, 'Malays', 'Female', '80 Years & Over', 5502, 1),
#  (2022, 'Malays', 'Female', '85 Years & Over', 2548, 1),
#  (2022, 'Malays', 'Female', '90 Years & Over', 767, 1),
#  (2022, 'Chinese', 'Male', '0 - 4 Years', 56990, 0),
#  (2022, 'Chinese', 'Male', '5 - 9 Years', 66574, 0),
#  (2022, 'Chinese', 'Male', '10 - 14 Years', 66620, 0),
#  (2022, 'Chinese', 'Male', '15 - 19 Years', 66618, 0),
#  (2022, 'Chinese', 'Male', '20 - 24 Years', 78315, 0),
#  (2022, 'Chinese', 'Male', '25 - 29 Years', 89239, 0),
#  (2022, 'Chinese', 'Male', '30 - 34 Years', 93531, 0),
#  (2022, 'Chinese', 'Male', '35 - 39 Years', 81017, 0),
#  (2022, 'Chinese', 'Male', '40 - 44 Years', 85987, 0),
#  (2022, 'Chinese', 'Male', '45 - 49 Years', 91660, 0),
#  (2022, 'Chinese', 'Male', '50 - 54 Years', 91625, 0),
#  (2022, 'Chinese', 'Male', '55 - 59 Years', 100734, 0),
#  (2022, 'Chinese', 'Male', '60 - 64 Years', 104416, 0),
#  (2022, 'Chinese', 'Male', '65 - 69 Years', 94586, 0),
#  (2022, 'Chinese', 'Male', '70 - 74 Years', 72830, 0),
#  (2022, 'Chinese', 'Male', '75 - 79 Years', 39883, 0),
#  (2022, 'Chinese', 'Male', '80 - 84 Years', 26324, 0),
#  (2022, 'Chinese', 'Male', '85 - 89 Years', 11804, 0),
#  (2022, 'Chinese', 'Male', '65 Years & Over', 250888, 0),
#  (2022, 'Chinese', 'Male', '70 Years & Over', 156302, 0),
#  (2022, 'Chinese', 'Male', '75 Years & Over', 83472, 0),
#  (2022, 'Chinese', 'Male', '80 Years & Over', 43589, 0),
#  (2022, 'Chinese', 'Male', '85 Years & Over', 17265, 0),
#  (2022, 'Chinese', 'Male', '90 Years & Over', 5461, 0),
#  (2022, 'Chinese', 'Female', '0 - 4 Years', 54332, 1),
#  (2022, 'Chinese', 'Female', '5 - 9 Years', 62614, 1),
#  (2022, 'Chinese', 'Female', '10 - 14 Years', 62651, 1),
#  (2022, 'Chinese', 'Female', '15 - 19 Years', 62854, 1),
#  (2022, 'Chinese', 'Female', '20 - 24 Years', 72211, 1),
#  (2022, 'Chinese', 'Female', '25 - 29 Years', 82649, 1),
#  (2022, 'Chinese', 'Female', '30 - 34 Years', 89758, 1),
#  (2022, 'Chinese', 'Female', '35 - 39 Years', 81748, 1),
#  (2022, 'Chinese', 'Female', '40 - 44 Years', 90353, 1),
#  (2022, 'Chinese', 'Female', '45 - 49 Years', 98721, 1),
#  (2022, 'Chinese', 'Female', '50 - 54 Years', 99284, 1),
#  (2022, 'Chinese', 'Female', '55 - 59 Years', 103942, 1),
#  (2022, 'Chinese', 'Female', '60 - 64 Years', 107067, 1),
#  (2022, 'Chinese', 'Female', '65 - 69 Years', 98777, 1),
#  (2022, 'Chinese', 'Female', '70 - 74 Years', 79882, 1),
#  (2022, 'Chinese', 'Female', '75 - 79 Years', 48007, 1),
#  (2022, 'Chinese', 'Female', '80 - 84 Years', 37179, 1),
#  (2022, 'Chinese', 'Female', '85 - 89 Years', 19924, 1),
#  (2022, 'Chinese', 'Female', '65 Years & Over', 297942, 1),
#  (2022, 'Chinese', 'Female', '70 Years & Over', 199165, 1),
#  (2022, 'Chinese', 'Female', '75 Years & Over', 119283, 1),
#  (2022, 'Chinese', 'Female', '80 Years & Over', 71276, 1),
#  (2022, 'Chinese', 'Female', '85 Years & Over', 34097, 1),
#  (2022, 'Chinese', 'Female', '90 Years & Over', 14173, 1),
#  (2022, 'Indians', 'Male', '0 - 4 Years', 6356, 0),
#  (2022, 'Indians', 'Male', '5 - 9 Years', 6853, 0),
#  (2022, 'Indians', 'Male', '10 - 14 Years', 7436, 0),
#  (2022, 'Indians', 'Male', '15 - 19 Years', 8682, 0),
#  (2022, 'Indians', 'Male', '20 - 24 Years', 10079, 0),
#  (2022, 'Indians', 'Male', '25 - 29 Years', 10226, 0),
#  (2022, 'Indians', 'Male', '30 - 34 Years', 10006, 0),
#  (2022, 'Indians', 'Male', '35 - 39 Years', 8945, 0),
#  (2022, 'Indians', 'Male', '40 - 44 Years', 8308, 0),
#  (2022, 'Indians', 'Male', '45 - 49 Years', 8941, 0),
#  (2022, 'Indians', 'Male', '50 - 54 Years', 10363, 0),
#  (2022, 'Indians', 'Male', '55 - 59 Years', 10924, 0),
#  (2022, 'Indians', 'Male', '60 - 64 Years', 10069, 0),
#  (2022, 'Indians', 'Male', '65 - 69 Years', 7317, 0),
#  (2022, 'Indians', 'Male', '70 - 74 Years', 4937, 0),
#  (2022, 'Indians', 'Male', '75 - 79 Years', 2252, 0),
#  (2022, 'Indians', 'Male', '80 - 84 Years', 1278, 0),
#  (2022, 'Indians', 'Male', '85 - 89 Years', 739, 0),
#  (2022, 'Indians', 'Male', '65 Years & Over', 17275, 0),
#  (2022, 'Indians', 'Male', '70 Years & Over', 9958, 0),
#  (2022, 'Indians', 'Male', '75 Years & Over', 5021, 0),
#  (2022, 'Indians', 'Male', '80 Years & Over', 2769, 0),
#  (2022, 'Indians', 'Male', '85 Years & Over', 1491, 0),
#  (2022, 'Indians', 'Male', '90 Years & Over', 752, 0),
#  (2022, 'Indians', 'Female', '0 - 4 Years', 6046, 1),
#  (2022, 'Indians', 'Female', '5 - 9 Years', 6470, 1),
#  (2022, 'Indians', 'Female', '10 - 14 Years', 7366, 1),
#  (2022, 'Indians', 'Female', '15 - 19 Years', 8550, 1),
#  (2022, 'Indians', 'Female', '20 - 24 Years', 9053, 1),
#  (2022, 'Indians', 'Female', '25 - 29 Years', 9552, 1),
#  (2022, 'Indians', 'Female', '30 - 34 Years', 9757, 1),
#  (2022, 'Indians', 'Female', '35 - 39 Years', 8484, 1),
#  (2022, 'Indians', 'Female', '40 - 44 Years', 8595, 1),
#  (2022, 'Indians', 'Female', '45 - 49 Years', 8940, 1),
#  (2022, 'Indians', 'Female', '50 - 54 Years', 9204, 1),
#  (2022, 'Indians', 'Female', '55 - 59 Years', 10189, 1),
#  (2022, 'Indians', 'Female', '60 - 64 Years', 9653, 1),
#  (2022, 'Indians', 'Female', '65 - 69 Years', 7659, 1),
#  (2022, 'Indians', 'Female', '70 - 74 Years', 5745, 1),
#  (2022, 'Indians', 'Female', '75 - 79 Years', 2962, 1),
#  (2022, 'Indians', 'Female', '80 - 84 Years', 2135, 1),
#  (2022, 'Indians', 'Female', '85 - 89 Years', 1166, 1),
#  (2022, 'Indians', 'Female', '65 Years & Over', 20219, 1),
#  (2022, 'Indians', 'Female', '70 Years & Over', 12560, 1),
#  (2022, 'Indians', 'Female', '75 Years & Over', 6815, 1),
#  (2022, 'Indians', 'Female', '80 Years & Over', 3853, 1),
#  (2022, 'Indians', 'Female', '85 Years & Over', 1718, 1),
#  (2022, 'Indians', 'Female', '90 Years & Over', 552, 1),
#  (2022, 'Other Ethnic Groups', 'Male', '0 - 4 Years', 2634, 0),
#  (2022, 'Other Ethnic Groups', 'Male', '5 - 9 Years', 2695, 0),
#  (2022, 'Other Ethnic Groups', 'Male', '10 - 14 Years', 2452, 0),
#  (2022, 'Other Ethnic Groups', 'Male', '15 - 19 Years', 2194, 0),
#  (2022, 'Other Ethnic Groups', 'Male', '20 - 24 Years', 2463, 0),
#  (2022, 'Other Ethnic Groups', 'Male', '25 - 29 Years', 2331, 0),
#  (2022, 'Other Ethnic Groups', 'Male', '30 - 34 Years', 1890, 0),
#  (2022, 'Other Ethnic Groups', 'Male', '35 - 39 Years', 1434, 0),
#  (2022, 'Other Ethnic Groups', 'Male', '40 - 44 Years', 1312, 0),
#  (2022, 'Other Ethnic Groups', 'Male', '45 - 49 Years', 1527, 0),
#  (2022, 'Other Ethnic Groups', 'Male', '50 - 54 Years', 1544, 0),
#  (2022, 'Other Ethnic Groups', 'Male', '55 - 59 Years', 1514, 0),
#  (2022, 'Other Ethnic Groups', 'Male', '60 - 64 Years', 1300, 0),
#  (2022, 'Other Ethnic Groups', 'Male', '65 - 69 Years', 1017, 0),
#  (2022, 'Other Ethnic Groups', 'Male', '70 - 74 Years', 768, 0),
#  (2022, 'Other Ethnic Groups', 'Male', '75 - 79 Years', 370, 0),
#  (2022, 'Other Ethnic Groups', 'Male', '80 - 84 Years', 236, 0),
#  (2022, 'Other Ethnic Groups', 'Male', '85 - 89 Years', 155, 0),
#  (2022, 'Other Ethnic Groups', 'Male', '65 Years & Over', 2659, 0),
#  (2022, 'Other Ethnic Groups', 'Male', '70 Years & Over', 1642, 0),
#  (2022, 'Other Ethnic Groups', 'Male', '75 Years & Over', 874, 0),
#  (2022, 'Other Ethnic Groups', 'Male', '80 Years & Over', 504, 0),
#  (2022, 'Other Ethnic Groups', 'Male', '85 Years & Over', 268, 0),
#  (2022, 'Other Ethnic Groups', 'Male', '90 Years & Over', 113, 0),
#  (2022, 'Other Ethnic Groups', 'Female', '0 - 4 Years', 2711, 1),
#  (2022, 'Other Ethnic Groups', 'Female', '5 - 9 Years', 2748, 1),
#  (2022, 'Other Ethnic Groups', 'Female', '10 - 14 Years', 2458, 1),
#  (2022, 'Other Ethnic Groups', 'Female', '15 - 19 Years', 2140, 1),
#  (2022, 'Other Ethnic Groups', 'Female', '20 - 24 Years', 1965, 1),
#  (2022, 'Other Ethnic Groups', 'Female', '25 - 29 Years', 1734, 1),
#  (2022, 'Other Ethnic Groups', 'Female', '30 - 34 Years', 2083, 1),
#  (2022, 'Other Ethnic Groups', 'Female', '35 - 39 Years', 2462, 1),
#  (2022, 'Other Ethnic Groups', 'Female', '40 - 44 Years', 2102, 1),
#  (2022, 'Other Ethnic Groups', 'Female', '45 - 49 Years', 1953, 1),
#  (2022, 'Other Ethnic Groups', 'Female', '50 - 54 Years', 1941, 1),
#  (2022, 'Other Ethnic Groups', 'Female', '55 - 59 Years', 1673, 1),
#  (2022, 'Other Ethnic Groups', 'Female', '60 - 64 Years', 1485, 1),
#  (2022, 'Other Ethnic Groups', 'Female', '65 - 69 Years', 1024, 1),
#  (2022, 'Other Ethnic Groups', 'Female', '70 - 74 Years', 757, 1),
#  (2022, 'Other Ethnic Groups', 'Female', '75 - 79 Years', 410, 1),
#  (2022, 'Other Ethnic Groups', 'Female', '80 - 84 Years', 347, 1),
#  (2022, 'Other Ethnic Groups', 'Female', '85 - 89 Years', 265, 1),
#  (2022, 'Other Ethnic Groups', 'Female', '65 Years & Over', 3010, 1),
#  (2022, 'Other Ethnic Groups', 'Female', '70 Years & Over', 1986, 1),
#  (2022, 'Other Ethnic Groups', 'Female', '75 Years & Over', 1229, 1),
#  (2022, 'Other Ethnic Groups', 'Female', '80 Years & Over', 819, 1),
#  (2022, 'Other Ethnic Groups', 'Female', '85 Years & Over', 472, 1),
#  (2022, 'Other Ethnic Groups', 'Female', '90 Years & Over', 207, 1),
#  (2021, 'All ethnicity', 'Male', '0 - 4 Years', 86634, 0),
#  (2021, 'All ethnicity', 'Male', '5 - 9 Years', 92974, 0),
#  (2021, 'All ethnicity', 'Male', '10 - 14 Years', 91619, 0),
#  (2021, 'All ethnicity', 'Male', '15 - 19 Years', 95489, 0),
#  (2021, 'All ethnicity', 'Male', '20 - 24 Years', 115291, 0),
#  (2021, 'All ethnicity', 'Male', '25 - 29 Years', 125045, 0),
#  (2021, 'All ethnicity', 'Male', '30 - 34 Years', 123336, 0),
#  (2021, 'All ethnicity', 'Male', '35 - 39 Years', 110754, 0),
#  (2021, 'All ethnicity', 'Male', '40 - 44 Years', 108442, 0),
#  (2021, 'All ethnicity', 'Male', '45 - 49 Years', 116463, 0),
#  (2021, 'All ethnicity', 'Male', '50 - 54 Years', 118139, 0),
#  (2021, 'All ethnicity', 'Male', '55 - 59 Years', 134517, 0),
#  (2021, 'All ethnicity', 'Male', '60 - 64 Years', 133032, 0),
#  (2021, 'All ethnicity', 'Male', '65 - 69 Years', 110565, 0),
#  (2021, 'All ethnicity', 'Male', '70 - 74 Years', 83165, 0),
#  (2021, 'All ethnicity', 'Male', '75 - 79 Years', 39270, 0),
#  (2021, 'All ethnicity', 'Male', '80 - 84 Years', 28927, 0),
#  (2021, 'All ethnicity', 'Male', '85 - 89 Years', 13621, 0),
#  (2021, 'All ethnicity', 'Male', '65 Years & Over', 282102, 0),
#  (2021, 'All ethnicity', 'Male', '70 Years & Over', 171537, 0),
#  (2021, 'All ethnicity', 'Male', '75 Years & Over', 88372, 0),
#  (2021, 'All ethnicity', 'Male', '80 Years & Over', 49102, 0),
#  (2021, 'All ethnicity', 'Male', '85 Years & Over', 20175, 0),
#  (2021, 'All ethnicity', 'Male', '90 Years & Over', 6554, 0),
#  (2021, 'All ethnicity', 'Female', '0 - 4 Years', 82703, 1),
#  (2021, 'All ethnicity', 'Female', '5 - 9 Years', 87658, 1),
#  (2021, 'All ethnicity', 'Female', '10 - 14 Years', 86743, 1),
#  (2021, 'All ethnicity', 'Female', '15 - 19 Years', 90221, 1),
#  (2021, 'All ethnicity', 'Female', '20 - 24 Years', 105414, 1),
#  (2021, 'All ethnicity', 'Female', '25 - 29 Years', 115847, 1),
#  (2021, 'All ethnicity', 'Female', '30 - 34 Years', 117720, 1),
#  (2021, 'All ethnicity', 'Female', '35 - 39 Years', 110654, 1),
#  (2021, 'All ethnicity', 'Female', '40 - 44 Years', 113553, 1),
#  (2021, 'All ethnicity', 'Female', '45 - 49 Years', 122893, 1),
#  (2021, 'All ethnicity', 'Female', '50 - 54 Years', 124228, 1),
#  (2021, 'All ethnicity', 'Female', '55 - 59 Years', 136481, 1),
#  (2021, 'All ethnicity', 'Female', '60 - 64 Years', 134976, 1),
#  (2021, 'All ethnicity', 'Female', '65 - 69 Years', 115632, 1),
#  (2021, 'All ethnicity', 'Female', '70 - 74 Years', 92386, 1),
#  (2021, 'All ethnicity', 'Female', '75 - 79 Years', 48443, 1),
#  (2021, 'All ethnicity', 'Female', '80 - 84 Years', 40500, 1),
#  (2021, 'All ethnicity', 'Female', '85 - 89 Years', 23167, 1),
#  (2021, 'All ethnicity', 'Female', '65 Years & Over', 335263, 1),
#  (2021, 'All ethnicity', 'Female', '70 Years & Over', 219631, 1),
#  (2021, 'All ethnicity', 'Female', '75 Years & Over', 127245, 1),
#  (2021, 'All ethnicity', 'Female', '80 Years & Over', 78802, 1),
#  (2021, 'All ethnicity', 'Female', '85 Years & Over', 38302, 1),
#  (2021, 'All ethnicity', 'Female', '90 Years & Over', 15135, 1),
#  (2021, 'Malays', 'Male', '0 - 4 Years', 20003, 0),
#  (2021, 'Malays', 'Male', '5 - 9 Years', 16886, 0),
#  (2021, 'Malays', 'Male', '10 - 14 Years', 16072, 0),
#  (2021, 'Malays', 'Male', '15 - 19 Years', 18033, 0),
#  (2021, 'Malays', 'Male', '20 - 24 Years', 22069, 0),
#  (2021, 'Malays', 'Male', '25 - 29 Years', 24225, 0),
#  (2021, 'Malays', 'Male', '30 - 34 Years', 23124, 0),
#  (2021, 'Malays', 'Male', '35 - 39 Years', 18853, 0),
#  (2021, 'Malays', 'Male', '40 - 44 Years', 14064, 0),
#  (2021, 'Malays', 'Male', '45 - 49 Years', 14313, 0),
#  (2021, 'Malays', 'Male', '50 - 54 Years', 15924, 0),
#  (2021, 'Malays', 'Male', '55 - 59 Years', 20107, 0),
#  (2021, 'Malays', 'Male', '60 - 64 Years', 17530, 0),
#  (2021, 'Malays', 'Male', '65 - 69 Years', 12145, 0),
#  (2021, 'Malays', 'Male', '70 - 74 Years', 7495, 0),
#  (2021, 'Malays', 'Male', '75 - 79 Years', 2860, 0),
#  (2021, 'Malays', 'Male', '80 - 84 Years', 2127, 0),
#  (2021, 'Malays', 'Male', '85 - 89 Years', 1094, 0),
#  (2021, 'Malays', 'Male', '65 Years & Over', 26200, 0),
#  (2021, 'Malays', 'Male', '70 Years & Over', 14055, 0),
#  (2021, 'Malays', 'Male', '75 Years & Over', 6560, 0),
#  (2021, 'Malays', 'Male', '80 Years & Over', 3700, 0),
#  (2021, 'Malays', 'Male', '85 Years & Over', 1573, 0),
#  (2021, 'Malays', 'Male', '90 Years & Over', 479, 0),
#  (2021, 'Malays', 'Female', '0 - 4 Years', 19079, 1),
#  (2021, 'Malays', 'Female', '5 - 9 Years', 16021, 1),
#  (2021, 'Malays', 'Female', '10 - 14 Years', 15130, 1),
#  (2021, 'Malays', 'Female', '15 - 19 Years', 16950, 1),
#  (2021, 'Malays', 'Female', '20 - 24 Years', 20410, 1),
#  (2021, 'Malays', 'Female', '25 - 29 Years', 22770, 1),
#  (2021, 'Malays', 'Female', '30 - 34 Years', 21862, 1),
#  (2021, 'Malays', 'Female', '35 - 39 Years', 17857, 1),
#  (2021, 'Malays', 'Female', '40 - 44 Years', 13613, 1),
#  (2021, 'Malays', 'Female', '45 - 49 Years', 14026, 1),
#  (2021, 'Malays', 'Female', '50 - 54 Years', 16275, 1),
#  (2021, 'Malays', 'Female', '55 - 59 Years', 20135, 1),
#  (2021, 'Malays', 'Female', '60 - 64 Years', 17488, 1),
#  (2021, 'Malays', 'Female', '65 - 69 Years', 12944, 1),
#  (2021, 'Malays', 'Female', '70 - 74 Years', 8618, 1),
#  (2021, 'Malays', 'Female', '75 - 79 Years', 3713, 1),
#  (2021, 'Malays', 'Female', '80 - 84 Years', 2843, 1),
#  (2021, 'Malays', 'Female', '85 - 89 Years', 1860, 1),
#  (2021, 'Malays', 'Female', '65 Years & Over', 30718, 1),
#  (2021, 'Malays', 'Female', '70 Years & Over', 17774, 1),
#  (2021, 'Malays', 'Female', '75 Years & Over', 9156, 1),
#  (2021, 'Malays', 'Female', '80 Years & Over', 5443, 1),
#  (2021, 'Malays', 'Female', '85 Years & Over', 2600, 1),
#  (2021, 'Malays', 'Female', '90 Years & Over', 740, 1),
#  (2021, 'Chinese', 'Male', '0 - 4 Years', 57749, 0),
#  (2021, 'Chinese', 'Male', '5 - 9 Years', 66787, 0),
#  (2021, 'Chinese', 'Male', '10 - 14 Years', 65634, 0),
#  (2021, 'Chinese', 'Male', '15 - 19 Years', 66746, 0),
#  (2021, 'Chinese', 'Male', '20 - 24 Years', 80892, 0),
#  (2021, 'Chinese', 'Male', '25 - 29 Years', 88720, 0),
#  (2021, 'Chinese', 'Male', '30 - 34 Years', 88891, 0),
#  (2021, 'Chinese', 'Male', '35 - 39 Years', 81907, 0),
#  (2021, 'Chinese', 'Male', '40 - 44 Years', 85187, 0),
#  (2021, 'Chinese', 'Male', '45 - 49 Years', 91586, 0),
#  (2021, 'Chinese', 'Male', '50 - 54 Years', 90478, 0),
#  (2021, 'Chinese', 'Male', '55 - 59 Years', 102280, 0),
#  (2021, 'Chinese', 'Male', '60 - 64 Years', 104601, 0),
#  (2021, 'Chinese', 'Male', '65 - 69 Years', 90609, 0),
#  (2021, 'Chinese', 'Male', '70 - 74 Years', 70247, 0),
#  (2021, 'Chinese', 'Male', '75 - 79 Years', 34344, 0),
#  (2021, 'Chinese', 'Male', '80 - 84 Years', 25342, 0),
#  (2021, 'Chinese', 'Male', '85 - 89 Years', 11607, 0),
#  (2021, 'Chinese', 'Male', '65 Years & Over', 237372, 0),
#  (2021, 'Chinese', 'Male', '70 Years & Over', 146763, 0),
#  (2021, 'Chinese', 'Male', '75 Years & Over', 76516, 0),
#  (2021, 'Chinese', 'Male', '80 Years & Over', 42172, 0),
#  (2021, 'Chinese', 'Male', '85 Years & Over', 16830, 0),
#  (2021, 'Chinese', 'Male', '90 Years & Over', 5223, 0),
#  (2021, 'Chinese', 'Female', '0 - 4 Years', 55009, 1),
#  (2021, 'Chinese', 'Female', '5 - 9 Years', 62520, 1),
#  (2021, 'Chinese', 'Female', '10 - 14 Years', 61885, 1),
#  (2021, 'Chinese', 'Female', '15 - 19 Years', 62870, 1),
#  (2021, 'Chinese', 'Female', '20 - 24 Years', 74150, 1),
#  (2021, 'Chinese', 'Female', '25 - 29 Years', 82034, 1),
#  (2021, 'Chinese', 'Female', '30 - 34 Years', 84969, 1),
#  (2021, 'Chinese', 'Female', '35 - 39 Years', 82452, 1),
#  (2021, 'Chinese', 'Female', '40 - 44 Years', 89887, 1),
#  (2021, 'Chinese', 'Female', '45 - 49 Years', 98284, 1),
#  (2021, 'Chinese', 'Female', '50 - 54 Years', 97053, 1),
#  (2021, 'Chinese', 'Female', '55 - 59 Years', 104731, 1),
#  (2021, 'Chinese', 'Female', '60 - 64 Years', 106936, 1),
#  (2021, 'Chinese', 'Female', '65 - 69 Years', 94567, 1),
#  (2021, 'Chinese', 'Female', '70 - 74 Years', 77535, 1),
#  (2021, 'Chinese', 'Female', '75 - 79 Years', 41972, 1),
#  (2021, 'Chinese', 'Female', '80 - 84 Years', 35218, 1),
#  (2021, 'Chinese', 'Female', '85 - 89 Years', 19924, 1),
#  (2021, 'Chinese', 'Female', '65 Years & Over', 282886, 1),
#  (2021, 'Chinese', 'Female', '70 Years & Over', 188319, 1),
#  (2021, 'Chinese', 'Female', '75 Years & Over', 110784, 1),
#  (2021, 'Chinese', 'Female', '80 Years & Over', 68812, 1),
#  (2021, 'Chinese', 'Female', '85 Years & Over', 33594, 1),
#  (2021, 'Chinese', 'Female', '90 Years & Over', 13670, 1),
#  (2021, 'Indians', 'Male', '0 - 4 Years', 6305, 0),
#  (2021, 'Indians', 'Male', '5 - 9 Years', 6707, 0),
#  (2021, 'Indians', 'Male', '10 - 14 Years', 7542, 0),
#  (2021, 'Indians', 'Male', '15 - 19 Years', 8648, 0),
#  (2021, 'Indians', 'Male', '20 - 24 Years', 9926, 0),
#  (2021, 'Indians', 'Male', '25 - 29 Years', 10014, 0),
#  (2021, 'Indians', 'Male', '30 - 34 Years', 9589, 0),
#  (2021, 'Indians', 'Male', '35 - 39 Years', 8631, 0),
#  (2021, 'Indians', 'Male', '40 - 44 Years', 7932, 0),
#  (2021, 'Indians', 'Male', '45 - 49 Years', 9080, 0),
#  (2021, 'Indians', 'Male', '50 - 54 Years', 10265, 0),
#  (2021, 'Indians', 'Male', '55 - 59 Years', 10682, 0),
#  (2021, 'Indians', 'Male', '60 - 64 Years', 9669, 0),
#  (2021, 'Indians', 'Male', '65 - 69 Years', 6861, 0),
#  (2021, 'Indians', 'Male', '70 - 74 Years', 4664, 0),
#  (2021, 'Indians', 'Male', '75 - 79 Years', 1787, 0),
#  (2021, 'Indians', 'Male', '80 - 84 Years', 1218, 0),
#  (2021, 'Indians', 'Male', '85 - 89 Years', 766, 0),
#  (2021, 'Indians', 'Male', '65 Years & Over', 16035, 0),
#  (2021, 'Indians', 'Male', '70 Years & Over', 9174, 0),
#  (2021, 'Indians', 'Male', '75 Years & Over', 4510, 0),
#  (2021, 'Indians', 'Male', '80 Years & Over', 2723, 0),
#  (2021, 'Indians', 'Male', '85 Years & Over', 1505, 0),
#  (2021, 'Indians', 'Male', '90 Years & Over', 739, 0),
#  (2021, 'Indians', 'Female', '0 - 4 Years', 5991, 1),
#  (2021, 'Indians', 'Female', '5 - 9 Years', 6468, 1),
#  (2021, 'Indians', 'Female', '10 - 14 Years', 7422, 1),
#  (2021, 'Indians', 'Female', '15 - 19 Years', 8448, 1),
#  (2021, 'Indians', 'Female', '20 - 24 Years', 8965, 1),
#  (2021, 'Indians', 'Female', '25 - 29 Years', 9434, 1),
#  (2021, 'Indians', 'Female', '30 - 34 Years', 8991, 1),
#  (2021, 'Indians', 'Female', '35 - 39 Years', 8147, 1),
#  (2021, 'Indians', 'Female', '40 - 44 Years', 8201, 1),
#  (2021, 'Indians', 'Female', '45 - 49 Years', 8738, 1),
#  (2021, 'Indians', 'Female', '50 - 54 Years', 9025, 1),
#  (2021, 'Indians', 'Female', '55 - 59 Years', 10054, 1),
#  (2021, 'Indians', 'Female', '60 - 64 Years', 9198, 1),
#  (2021, 'Indians', 'Female', '65 - 69 Years', 7198, 1),
#  (2021, 'Indians', 'Female', '70 - 74 Years', 5506, 1),
#  (2021, 'Indians', 'Female', '75 - 79 Years', 2424, 1),
#  (2021, 'Indians', 'Female', '80 - 84 Years', 2071, 1),
#  (2021, 'Indians', 'Female', '85 - 89 Years', 1139, 1),
#  (2021, 'Indians', 'Female', '65 Years & Over', 18854, 1),
#  (2021, 'Indians', 'Female', '70 Years & Over', 11656, 1),
#  (2021, 'Indians', 'Female', '75 Years & Over', 6150, 1),
#  (2021, 'Indians', 'Female', '80 Years & Over', 3726, 1),
#  (2021, 'Indians', 'Female', '85 Years & Over', 1655, 1),
#  (2021, 'Indians', 'Female', '90 Years & Over', 516, 1),
#  (2021, 'Other Ethnic Groups', 'Male', '0 - 4 Years', 2577, 0),
#  (2021, 'Other Ethnic Groups', 'Male', '5 - 9 Years', 2594, 0),
#  (2021, 'Other Ethnic Groups', 'Male', '10 - 14 Years', 2371, 0),
#  (2021, 'Other Ethnic Groups', 'Male', '15 - 19 Years', 2062, 0),
#  (2021, 'Other Ethnic Groups', 'Male', '20 - 24 Years', 2404, 0),
#  (2021, 'Other Ethnic Groups', 'Male', '25 - 29 Years', 2086, 0),
#  (2021, 'Other Ethnic Groups', 'Male', '30 - 34 Years', 1732, 0),
#  (2021, 'Other Ethnic Groups', 'Male', '35 - 39 Years', 1363, 0),
#  (2021, 'Other Ethnic Groups', 'Male', '40 - 44 Years', 1259, 0),
#  (2021, 'Other Ethnic Groups', 'Male', '45 - 49 Years', 1484, 0),
#  (2021, 'Other Ethnic Groups', 'Male', '50 - 54 Years', 1472, 0),
#  (2021, 'Other Ethnic Groups', 'Male', '55 - 59 Years', 1448, 0),
#  (2021, 'Other Ethnic Groups', 'Male', '60 - 64 Years', 1232, 0),
#  (2021, 'Other Ethnic Groups', 'Male', '65 - 69 Years', 950, 0),
#  (2021, 'Other Ethnic Groups', 'Male', '70 - 74 Years', 759, 0),
#  (2021, 'Other Ethnic Groups', 'Male', '75 - 79 Years', 279, 0),
#  (2021, 'Other Ethnic Groups', 'Male', '80 - 84 Years', 240, 0),
#  (2021, 'Other Ethnic Groups', 'Male', '85 - 89 Years', 154, 0),
#  (2021, 'Other Ethnic Groups', 'Male', '65 Years & Over', 2495, 0),
#  (2021, 'Other Ethnic Groups', 'Male', '70 Years & Over', 1545, 0),
#  (2021, 'Other Ethnic Groups', 'Male', '75 Years & Over', 786, 0),
#  (2021, 'Other Ethnic Groups', 'Male', '80 Years & Over', 507, 0),
#  (2021, 'Other Ethnic Groups', 'Male', '85 Years & Over', 267, 0),
#  (2021, 'Other Ethnic Groups', 'Male', '90 Years & Over', 113, 0),
#  (2021, 'Other Ethnic Groups', 'Female', '0 - 4 Years', 2624, 1),
#  (2021, 'Other Ethnic Groups', 'Female', '5 - 9 Years', 2649, 1),
#  (2021, 'Other Ethnic Groups', 'Female', '10 - 14 Years', 2306, 1),
#  (2021, 'Other Ethnic Groups', 'Female', '15 - 19 Years', 1953, 1),
#  (2021, 'Other Ethnic Groups', 'Female', '20 - 24 Years', 1889, 1),
#  (2021, 'Other Ethnic Groups', 'Female', '25 - 29 Years', 1609, 1),
#  (2021, 'Other Ethnic Groups', 'Female', '30 - 34 Years', 1898, 1),
#  (2021, 'Other Ethnic Groups', 'Female', '35 - 39 Years', 2198, 1),
#  (2021, 'Other Ethnic Groups', 'Female', '40 - 44 Years', 1852, 1),
#  (2021, 'Other Ethnic Groups', 'Female', '45 - 49 Years', 1845, 1),
#  (2021, 'Other Ethnic Groups', 'Female', '50 - 54 Years', 1875, 1),
#  (2021, 'Other Ethnic Groups', 'Female', '55 - 59 Years', 1561, 1),
#  (2021, 'Other Ethnic Groups', 'Female', '60 - 64 Years', 1354, 1),
#  (2021, 'Other Ethnic Groups', 'Female', '65 - 69 Years', 923, 1),
#  (2021, 'Other Ethnic Groups', 'Female', '70 - 74 Years', 727, 1),
#  (2021, 'Other Ethnic Groups', 'Female', '75 - 79 Years', 334, 1),
#  (2021, 'Other Ethnic Groups', 'Female', '80 - 84 Years', 368, 1),
#  (2021, 'Other Ethnic Groups', 'Female', '85 - 89 Years', 244, 1),
#  (2021, 'Other Ethnic Groups', 'Female', '65 Years & Over', 2805, 1),
#  (2021, 'Other Ethnic Groups', 'Female', '70 Years & Over', 1882, 1),
#  (2021, 'Other Ethnic Groups', 'Female', '75 Years & Over', 1155, 1),
#  (2021, 'Other Ethnic Groups', 'Female', '80 Years & Over', 821, 1),
#  (2021, 'Other Ethnic Groups', 'Female', '85 Years & Over', 453, 1),
#  (2021, 'Other Ethnic Groups', 'Female', '90 Years & Over', 209, 1),
#  (2020, 'All ethnicity', 'Male', '0 - 4 Years', 88197, 0),
#  (2020, 'All ethnicity', 'Male', '5 - 9 Years', 91755, 0),
#  (2020, 'All ethnicity', 'Male', '10 - 14 Years', 93000, 0),
#  (2020, 'All ethnicity', 'Male', '15 - 19 Years', 99700, 0),
#  (2020, 'All ethnicity', 'Male', '20 - 24 Years', 117155, 0),
#  (2020, 'All ethnicity', 'Male', '25 - 29 Years', 128690, 0),
#  (2020, 'All ethnicity', 'Male', '30 - 34 Years', 120229, 0),
#  (2020, 'All ethnicity', 'Male', '35 - 39 Years', 112668, 0),
#  (2020, 'All ethnicity', 'Male', '40 - 44 Years', 109469, 0),
#  (2020, 'All ethnicity', 'Male', '45 - 49 Years', 120952, 0),
#  (2020, 'All ethnicity', 'Male', '50 - 54 Years', 123156, 0),
#  (2020, 'All ethnicity', 'Male', '55 - 59 Years', 137919, 0),
#  (2020, 'All ethnicity', 'Male', '60 - 64 Years', 132939, 0),
#  (2020, 'All ethnicity', 'Male', '65 - 69 Years', 107012, 0),
#  (2020, 'All ethnicity', 'Male', '70 - 74 Years', 77232, 0),
#  (2020, 'All ethnicity', 'Male', '75 - 79 Years', 38812, 0),
#  (2020, 'All ethnicity', 'Male', '80 - 84 Years', 26869, 0),
#  (2020, 'All ethnicity', 'Male', '85 - 89 Years', 13124, 0),
#  (2020, 'All ethnicity', 'Male', '65 Years & Over', 269195, 0),
#  (2020, 'All ethnicity', 'Male', '70 Years & Over', 162183, 0),
#  (2020, 'All ethnicity', 'Male', '75 Years & Over', 84951, 0),
#  (2020, 'All ethnicity', 'Male', '80 Years & Over', 46139, 0),
#  (2020, 'All ethnicity', 'Male', '85 Years & Over', 19270, 0),
#  (2020, 'All ethnicity', 'Male', '90 Years & Over', 6146, 0),
#  (2020, 'All ethnicity', 'Female', '0 - 4 Years', 84199, 1),
#  (2020, 'All ethnicity', 'Female', '5 - 9 Years', 86369, 1),
#  (2020, 'All ethnicity', 'Female', '10 - 14 Years', 88597, 1),
#  (2020, 'All ethnicity', 'Female', '15 - 19 Years', 94089, 1),
#  (2020, 'All ethnicity', 'Female', '20 - 24 Years', 108667, 1),
#  (2020, 'All ethnicity', 'Female', '25 - 29 Years', 119825, 1),
#  (2020, 'All ethnicity', 'Female', '30 - 34 Years', 115373, 1),
#  (2020, 'All ethnicity', 'Female', '35 - 39 Years', 113646, 1),
#  (2020, 'All ethnicity', 'Female', '40 - 44 Years', 114892, 1),
#  (2020, 'All ethnicity', 'Female', '45 - 49 Years', 127285, 1),
#  (2020, 'All ethnicity', 'Female', '50 - 54 Years', 128296, 1),
#  (2020, 'All ethnicity', 'Female', '55 - 59 Years', 139633, 1),
#  (2020, 'All ethnicity', 'Female', '60 - 64 Years', 135947, 1),
#  (2020, 'All ethnicity', 'Female', '65 - 69 Years', 112263, 1),
#  (2020, 'All ethnicity', 'Female', '70 - 74 Years', 86340, 1),
#  (2020, 'All ethnicity', 'Female', '75 - 79 Years', 48498, 1),
#  (2020, 'All ethnicity', 'Female', '80 - 84 Years', 37354, 1),
#  (2020, 'All ethnicity', 'Female', '85 - 89 Years', 22572, 1),
#  (2020, 'All ethnicity', 'Female', '65 Years & Over', 321349, 1),
#  (2020, 'All ethnicity', 'Female', '70 Years & Over', 209086, 1),
#  (2020, 'All ethnicity', 'Female', '75 Years & Over', 122746, 1),
#  (2020, 'All ethnicity', 'Female', '80 Years & Over', 74248, 1),
#  (2020, 'All ethnicity', 'Female', '85 Years & Over', 36894, 1),
#  (2020, 'All ethnicity', 'Female', '90 Years & Over', 14322, 1),
#  (2020, 'Malays', 'Male', '0 - 4 Years', 19756, 0),
#  (2020, 'Malays', 'Male', '5 - 9 Years', 16304, 0),
#  (2020, 'Malays', 'Male', '10 - 14 Years', 16457, 0),
#  (2020, 'Malays', 'Male', '15 - 19 Years', 18960, 0),
#  (2020, 'Malays', 'Male', '20 - 24 Years', 22433, 0),
#  (2020, 'Malays', 'Male', '25 - 29 Years', 24831, 0),
#  (2020, 'Malays', 'Male', '30 - 34 Years', 22223, 0),
#  (2020, 'Malays', 'Male', '35 - 39 Years', 18275, 0),
#  (2020, 'Malays', 'Male', '40 - 44 Years', 13425, 0),
#  (2020, 'Malays', 'Male', '45 - 49 Years', 14910, 0),
#  (2020, 'Malays', 'Male', '50 - 54 Years', 17199, 0),
#  (2020, 'Malays', 'Male', '55 - 59 Years', 20396, 0),
#  (2020, 'Malays', 'Male', '60 - 64 Years', 16943, 0),
#  (2020, 'Malays', 'Male', '65 - 69 Years', 11327, 0),
#  (2020, 'Malays', 'Male', '70 - 74 Years', 6821, 0),
#  (2020, 'Malays', 'Male', '75 - 79 Years', 2820, 0),
#  (2020, 'Malays', 'Male', '80 - 84 Years', 2127, 0),
#  (2020, 'Malays', 'Male', '85 - 89 Years', 1078, 0),
#  (2020, 'Malays', 'Male', '65 Years & Over', 24650, 0),
#  (2020, 'Malays', 'Male', '70 Years & Over', 13323, 0),
#  (2020, 'Malays', 'Male', '75 Years & Over', 6502, 0),
#  (2020, 'Malays', 'Male', '80 Years & Over', 3682, 0),
#  (2020, 'Malays', 'Male', '85 Years & Over', 1555, 0),
#  (2020, 'Malays', 'Male', '90 Years & Over', 477, 0),
#  (2020, 'Malays', 'Female', '0 - 4 Years', 18740, 1),
#  (2020, 'Malays', 'Female', '5 - 9 Years', 15422, 1),
#  (2020, 'Malays', 'Female', '10 - 14 Years', 15609, 1),
#  (2020, 'Malays', 'Female', '15 - 19 Years', 17654, 1),
#  (2020, 'Malays', 'Female', '20 - 24 Years', 21025, 1),
#  (2020, 'Malays', 'Female', '25 - 29 Years', 23271, 1),
#  (2020, 'Malays', 'Female', '30 - 34 Years', 21275, 1),
#  (2020, 'Malays', 'Female', '35 - 39 Years', 17462, 1),
#  (2020, 'Malays', 'Female', '40 - 44 Years', 13193, 1),
#  (2020, 'Malays', 'Female', '45 - 49 Years', 14835, 1),
#  (2020, 'Malays', 'Female', '50 - 54 Years', 17656, 1),
#  (2020, 'Malays', 'Female', '55 - 59 Years', 20586, 1),
#  (2020, 'Malays', 'Female', '60 - 64 Years', 17189, 1),
#  (2020, 'Malays', 'Female', '65 - 69 Years', 12349, 1),
#  (2020, 'Malays', 'Female', '70 - 74 Years', 7877, 1),
#  (2020, 'Malays', 'Female', '75 - 79 Years', 3718, 1),
#  (2020, 'Malays', 'Female', '80 - 84 Years', 2801, 1),
#  (2020, 'Malays', 'Female', '85 - 89 Years', 1799, 1),
#  (2020, 'Malays', 'Female', '65 Years & Over', 29275, 1),
#  (2020, 'Malays', 'Female', '70 Years & Over', 16926, 1),
#  (2020, 'Malays', 'Female', '75 Years & Over', 9049, 1),
#  (2020, 'Malays', 'Female', '80 Years & Over', 5331, 1),
#  (2020, 'Malays', 'Female', '85 Years & Over', 2530, 1),
#  (2020, 'Malays', 'Female', '90 Years & Over', 731, 1),
#  (2020, 'Chinese', 'Male', '0 - 4 Years', 59427, 0),
#  (2020, 'Chinese', 'Male', '5 - 9 Years', 66075, 0),
#  (2020, 'Chinese', 'Male', '10 - 14 Years', 66291, 0),
#  (2020, 'Chinese', 'Male', '15 - 19 Years', 69768, 0),
#  (2020, 'Chinese', 'Male', '20 - 24 Years', 82555, 0),
#  (2020, 'Chinese', 'Male', '25 - 29 Years', 91489, 0),
#  (2020, 'Chinese', 'Male', '30 - 34 Years', 86850, 0),
#  (2020, 'Chinese', 'Male', '35 - 39 Years', 84404, 0),
#  (2020, 'Chinese', 'Male', '40 - 44 Years', 86770, 0),
#  (2020, 'Chinese', 'Male', '45 - 49 Years', 94804, 0),
#  (2020, 'Chinese', 'Male', '50 - 54 Years', 93739, 0),
#  (2020, 'Chinese', 'Male', '55 - 59 Years', 105320, 0),
#  (2020, 'Chinese', 'Male', '60 - 64 Years', 105211, 0),
#  (2020, 'Chinese', 'Male', '65 - 69 Years', 88240, 0),
#  (2020, 'Chinese', 'Male', '70 - 74 Years', 65389, 0),
#  (2020, 'Chinese', 'Male', '75 - 79 Years', 33929, 0),
#  (2020, 'Chinese', 'Male', '80 - 84 Years', 23302, 0),
#  (2020, 'Chinese', 'Male', '85 - 89 Years', 11058, 0),
#  (2020, 'Chinese', 'Male', '65 Years & Over', 226782, 0),
#  (2020, 'Chinese', 'Male', '70 Years & Over', 138542, 0),
#  (2020, 'Chinese', 'Male', '75 Years & Over', 73153, 0),
#  (2020, 'Chinese', 'Male', '80 Years & Over', 39224, 0),
#  (2020, 'Chinese', 'Male', '85 Years & Over', 15922, 0),
#  (2020, 'Chinese', 'Male', '90 Years & Over', 4864, 0),
#  (2020, 'Chinese', 'Female', '0 - 4 Years', 56708, 1),
#  (2020, 'Chinese', 'Female', '5 - 9 Years', 61734, 1),
#  (2020, 'Chinese', 'Female', '10 - 14 Years', 62776, 1),
#  (2020, 'Chinese', 'Female', '15 - 19 Years', 65797, 1),
#  (2020, 'Chinese', 'Female', '20 - 24 Years', 76437, 1),
#  (2020, 'Chinese', 'Female', '25 - 29 Years', 84997, 1),
#  (2020, 'Chinese', 'Female', '30 - 34 Years', 83266, 1),
#  (2020, 'Chinese', 'Female', '35 - 39 Years', 85583, 1),
#  (2020, 'Chinese', 'Female', '40 - 44 Years', 91674, 1),
#  (2020, 'Chinese', 'Female', '45 - 49 Years', 101505, 1),
#  (2020, 'Chinese', 'Female', '50 - 54 Years', 99324, 1),
#  (2020, 'Chinese', 'Female', '55 - 59 Years', 106974, 1),
#  (2020, 'Chinese', 'Female', '60 - 64 Years', 108204, 1),
#  (2020, 'Chinese', 'Female', '65 - 69 Years', 91937, 1),
#  (2020, 'Chinese', 'Female', '70 - 74 Years', 72608, 1),
#  (2020, 'Chinese', 'Female', '75 - 79 Years', 41996, 1),
#  (2020, 'Chinese', 'Female', '80 - 84 Years', 32158, 1),
#  (2020, 'Chinese', 'Female', '85 - 89 Years', 19448, 1),
#  (2020, 'Chinese', 'Female', '65 Years & Over', 271057, 1),
#  (2020, 'Chinese', 'Female', '70 Years & Over', 179120, 1),
#  (2020, 'Chinese', 'Female', '75 Years & Over', 106512, 1),
#  (2020, 'Chinese', 'Female', '80 Years & Over', 64516, 1),
#  (2020, 'Chinese', 'Female', '85 Years & Over', 32358, 1),
#  (2020, 'Chinese', 'Female', '90 Years & Over', 12910, 1),
#  (2020, 'Indians', 'Male', '0 - 4 Years', 6447, 0),
#  (2020, 'Indians', 'Male', '5 - 9 Years', 6736, 0),
#  (2020, 'Indians', 'Male', '10 - 14 Years', 7872, 0),
#  (2020, 'Indians', 'Male', '15 - 19 Years', 8852, 0),
#  (2020, 'Indians', 'Male', '20 - 24 Years', 9884, 0),
#  (2020, 'Indians', 'Male', '25 - 29 Years', 10310, 0),
#  (2020, 'Indians', 'Male', '30 - 34 Years', 9515, 0),
#  (2020, 'Indians', 'Male', '35 - 39 Years', 8667, 0),
#  (2020, 'Indians', 'Male', '40 - 44 Years', 8012, 0),
#  (2020, 'Indians', 'Male', '45 - 49 Years', 9673, 0),
#  (2020, 'Indians', 'Male', '50 - 54 Years', 10727, 0),
#  (2020, 'Indians', 'Male', '55 - 59 Years', 10768, 0),
#  (2020, 'Indians', 'Male', '60 - 64 Years', 9538, 0),
#  (2020, 'Indians', 'Male', '65 - 69 Years', 6520, 0),
#  (2020, 'Indians', 'Male', '70 - 74 Years', 4306, 0),
#  (2020, 'Indians', 'Male', '75 - 79 Years', 1771, 0),
#  (2020, 'Indians', 'Male', '80 - 84 Years', 1194, 0),
#  (2020, 'Indians', 'Male', '85 - 89 Years', 835, 0),
#  (2020, 'Indians', 'Male', '65 Years & Over', 15338, 0),
#  (2020, 'Indians', 'Male', '70 Years & Over', 8818, 0),
#  (2020, 'Indians', 'Male', '75 Years & Over', 4512, 0),
#  (2020, 'Indians', 'Male', '80 Years & Over', 2741, 0),
#  (2020, 'Indians', 'Male', '85 Years & Over', 1547, 0),
#  (2020, 'Indians', 'Male', '90 Years & Over', 712, 0),
#  (2020, 'Indians', 'Female', '0 - 4 Years', 6147, 1),
#  (2020, 'Indians', 'Female', '5 - 9 Years', 6551, 1),
#  (2020, 'Indians', 'Female', '10 - 14 Years', 7758, 1),
#  (2020, 'Indians', 'Female', '15 - 19 Years', 8573, 1),
#  (2020, 'Indians', 'Female', '20 - 24 Years', 9270, 1),
#  (2020, 'Indians', 'Female', '25 - 29 Years', 9940, 1),
#  (2020, 'Indians', 'Female', '30 - 34 Years', 9028, 1),
#  (2020, 'Indians', 'Female', '35 - 39 Years', 8548, 1),
#  (2020, 'Indians', 'Female', '40 - 44 Years', 8298, 1),
#  (2020, 'Indians', 'Female', '45 - 49 Years', 9070, 1),
#  (2020, 'Indians', 'Female', '50 - 54 Years', 9474, 1),
#  (2020, 'Indians', 'Female', '55 - 59 Years', 10450, 1),
#  (2020, 'Indians', 'Female', '60 - 64 Years', 9214, 1),
#  (2020, 'Indians', 'Female', '65 - 69 Years', 7056, 1),
#  (2020, 'Indians', 'Female', '70 - 74 Years', 5130, 1),
#  (2020, 'Indians', 'Female', '75 - 79 Years', 2429, 1),
#  (2020, 'Indians', 'Female', '80 - 84 Years', 2026, 1),
#  (2020, 'Indians', 'Female', '85 - 89 Years', 1068, 1),
#  (2020, 'Indians', 'Female', '65 Years & Over', 18200, 1),
#  (2020, 'Indians', 'Female', '70 Years & Over', 11144, 1),
#  (2020, 'Indians', 'Female', '75 Years & Over', 6014, 1),
#  (2020, 'Indians', 'Female', '80 Years & Over', 3585, 1),
#  (2020, 'Indians', 'Female', '85 Years & Over', 1559, 1),
#  (2020, 'Indians', 'Female', '90 Years & Over', 491, 1),
#  (2020, 'Other Ethnic Groups', 'Male', '0 - 4 Years', 2567, 0),
#  (2020, 'Other Ethnic Groups', 'Male', '5 - 9 Years', 2640, 0),
#  (2020, 'Other Ethnic Groups', 'Male', '10 - 14 Years', 2380, 0),
#  (2020, 'Other Ethnic Groups', 'Male', '15 - 19 Years', 2120, 0),
#  (2020, 'Other Ethnic Groups', 'Male', '20 - 24 Years', 2283, 0),
#  (2020, 'Other Ethnic Groups', 'Male', '25 - 29 Years', 2060, 0),
#  (2020, 'Other Ethnic Groups', 'Male', '30 - 34 Years', 1641, 0),
#  (2020, 'Other Ethnic Groups', 'Male', '35 - 39 Years', 1322, 0),
#  (2020, 'Other Ethnic Groups', 'Male', '40 - 44 Years', 1262, 0),
#  (2020, 'Other Ethnic Groups', 'Male', '45 - 49 Years', 1565, 0),
#  (2020, 'Other Ethnic Groups', 'Male', '50 - 54 Years', 1491, 0),
#  (2020, 'Other Ethnic Groups', 'Male', '55 - 59 Years', 1435, 0),
#  (2020, 'Other Ethnic Groups', 'Male', '60 - 64 Years', 1247, 0),
#  (2020, 'Other Ethnic Groups', 'Male', '65 - 69 Years', 925, 0),
#  (2020, 'Other Ethnic Groups', 'Male', '70 - 74 Years', 716, 0),
#  (2020, 'Other Ethnic Groups', 'Male', '75 - 79 Years', 292, 0),
#  (2020, 'Other Ethnic Groups', 'Male', '80 - 84 Years', 246, 0),
#  (2020, 'Other Ethnic Groups', 'Male', '85 - 89 Years', 153, 0),
#  (2020, 'Other Ethnic Groups', 'Male', '65 Years & Over', 2425, 0),
#  (2020, 'Other Ethnic Groups', 'Male', '70 Years & Over', 1500, 0),
#  (2020, 'Other Ethnic Groups', 'Male', '75 Years & Over', 784, 0),
#  (2020, 'Other Ethnic Groups', 'Male', '80 Years & Over', 492, 0),
#  (2020, 'Other Ethnic Groups', 'Male', '85 Years & Over', 246, 0),
#  (2020, 'Other Ethnic Groups', 'Male', '90 Years & Over', 93, 0),
#  (2020, 'Other Ethnic Groups', 'Female', '0 - 4 Years', 2604, 1),
#  (2020, 'Other Ethnic Groups', 'Female', '5 - 9 Years', 2662, 1),
#  (2020, 'Other Ethnic Groups', 'Female', '10 - 14 Years', 2454, 1),
#  (2020, 'Other Ethnic Groups', 'Female', '15 - 19 Years', 2065, 1),
#  (2020, 'Other Ethnic Groups', 'Female', '20 - 24 Years', 1935, 1),
#  (2020, 'Other Ethnic Groups', 'Female', '25 - 29 Years', 1617, 1),
#  (2020, 'Other Ethnic Groups', 'Female', '30 - 34 Years', 1804, 1),
#  (2020, 'Other Ethnic Groups', 'Female', '35 - 39 Years', 2053, 1),
#  (2020, 'Other Ethnic Groups', 'Female', '40 - 44 Years', 1727, 1),
#  (2020, 'Other Ethnic Groups', 'Female', '45 - 49 Years', 1875, 1),
#  (2020, 'Other Ethnic Groups', 'Female', '50 - 54 Years', 1842, 1),
#  (2020, 'Other Ethnic Groups', 'Female', '55 - 59 Years', 1623, 1),
#  (2020, 'Other Ethnic Groups', 'Female', '60 - 64 Years', 1340, 1),
#  (2020, 'Other Ethnic Groups', 'Female', '65 - 69 Years', 921, 1),
#  (2020, 'Other Ethnic Groups', 'Female', '70 - 74 Years', 725, 1),
#  (2020, 'Other Ethnic Groups', 'Female', '75 - 79 Years', 355, 1),
#  (2020, 'Other Ethnic Groups', 'Female', '80 - 84 Years', 369, 1),
#  (2020, 'Other Ethnic Groups', 'Female', '85 - 89 Years', 257, 1),
#  (2020, 'Other Ethnic Groups', 'Female', '65 Years & Over', 2817, 1),
#  (2020, 'Other Ethnic Groups', 'Female', '70 Years & Over', 1896, 1),
#  (2020, 'Other Ethnic Groups', 'Female', '75 Years & Over', 1171, 1),
#  (2020, 'Other Ethnic Groups', 'Female', '80 Years & Over', 816, 1),
#  (2020, 'Other Ethnic Groups', 'Female', '85 Years & Over', 447, 1),
#  (2020, 'Other Ethnic Groups', 'Female', '90 Years & Over', 190, 1),
#  (2019, 'All ethnicity', 'Male', '0 - 4 Years', 88687, 0),
#  (2019, 'All ethnicity', 'Male', '5 - 9 Years', 90607, 0),
#  (2019, 'All ethnicity', 'Male', '10 - 14 Years', 93006, 0),
#  (2019, 'All ethnicity', 'Male', '15 - 19 Years', 103282, 0),
#  (2019, 'All ethnicity', 'Male', '20 - 24 Years', 119121, 0),
#  (2019, 'All ethnicity', 'Male', '25 - 29 Years', 128542, 0),
#  (2019, 'All ethnicity', 'Male', '30 - 34 Years', 117060, 0),
#  (2019, 'All ethnicity', 'Male', '35 - 39 Years', 112135, 0),
#  (2019, 'All ethnicity', 'Male', '40 - 44 Years', 109569, 0),
#  (2019, 'All ethnicity', 'Male', '45 - 49 Years', 121482, 0),
#  (2019, 'All ethnicity', 'Male', '50 - 54 Years', 127510, 0),
#  (2019, 'All ethnicity', 'Male', '55 - 59 Years', 139419, 0),
#  (2019, 'All ethnicity', 'Male', '60 - 64 Years', 130175, 0),
#  (2019, 'All ethnicity', 'Male', '65 - 69 Years', 103193, 0),
#  (2019, 'All ethnicity', 'Male', '70 - 74 Years', 68035, 0),
#  (2019, 'All ethnicity', 'Male', '75 - 79 Years', 40165, 0),
#  (2019, 'All ethnicity', 'Male', '80 - 84 Years', 25137, 0),
#  (2019, 'All ethnicity', 'Male', '85 - 89 Years', 12132, 0),
#  (2019, 'All ethnicity', 'Male', '65 Years & Over', 254317, 0),
#  (2019, 'All ethnicity', 'Male', '70 Years & Over', 151124, 0),
#  (2019, 'All ethnicity', 'Male', '75 Years & Over', 83089, 0),
#  (2019, 'All ethnicity', 'Male', '80 Years & Over', 42924, 0),
#  (2019, 'All ethnicity', 'Male', '85 Years & Over', 17787, 0),
#  (2019, 'All ethnicity', 'Male', '90 Years & Over', 5655, 0),
#  (2019, 'All ethnicity', 'Female', '0 - 4 Years', 84338, 1),
#  (2019, 'All ethnicity', 'Female', '5 - 9 Years', 85577, 1),
#  (2019, 'All ethnicity', 'Female', '10 - 14 Years', 88465, 1),
#  (2019, 'All ethnicity', 'Female', '15 - 19 Years', 97135, 1),
#  (2019, 'All ethnicity', 'Female', '20 - 24 Years', 110818, 1),
#  (2019, 'All ethnicity', 'Female', '25 - 29 Years', 120040, 1),
#  (2019, 'All ethnicity', 'Female', '30 - 34 Years', 113052, 1),
#  (2019, 'All ethnicity', 'Female', '35 - 39 Years', 112894, 1),
#  (2019, 'All ethnicity', 'Female', '40 - 44 Years', 115042, 1),
#  (2019, 'All ethnicity', 'Female', '45 - 49 Years', 127943, 1),
#  (2019, 'All ethnicity', 'Female', '50 - 54 Years', 131353, 1),
#  (2019, 'All ethnicity', 'Female', '55 - 59 Years', 140960, 1),
#  (2019, 'All ethnicity', 'Female', '60 - 64 Years', 133724, 1),
#  (2019, 'All ethnicity', 'Female', '65 - 69 Years', 108336, 1),
#  (2019, 'All ethnicity', 'Female', '70 - 74 Years', 76294, 1),
#  (2019, 'All ethnicity', 'Female', '75 - 79 Years', 50627, 1),
#  (2019, 'All ethnicity', 'Female', '80 - 84 Years', 35053, 1),
#  (2019, 'All ethnicity', 'Female', '85 - 89 Years', 20988, 1),
#  (2019, 'All ethnicity', 'Female', '65 Years & Over', 304687, 1),
#  (2019, 'All ethnicity', 'Female', '70 Years & Over', 196351, 1),
#  (2019, 'All ethnicity', 'Female', '75 Years & Over', 120057, 1),
#  (2019, 'All ethnicity', 'Female', '80 Years & Over', 69430, 1),
#  (2019, 'All ethnicity', 'Female', '85 Years & Over', 34377, 1),
#  (2019, 'All ethnicity', 'Female', '90 Years & Over', 13389, 1),
#  (2019, 'Malays', 'Male', '0 - 4 Years', 19078, 0),
#  (2019, 'Malays', 'Male', '5 - 9 Years', 15928, 0),
#  (2019, 'Malays', 'Male', '10 - 14 Years', 16731, 0),
#  (2019, 'Malays', 'Male', '15 - 19 Years', 19763, 0),
#  (2019, 'Malays', 'Male', '20 - 24 Years', 22931, 0),
#  (2019, 'Malays', 'Male', '25 - 29 Years', 25044, 0),
#  (2019, 'Malays', 'Male', '30 - 34 Years', 21257, 0),
#  (2019, 'Malays', 'Male', '35 - 39 Years', 17402, 0),
#  (2019, 'Malays', 'Male', '40 - 44 Years', 13332, 0),
#  (2019, 'Malays', 'Male', '45 - 49 Years', 14913, 0),
#  (2019, 'Malays', 'Male', '50 - 54 Years', 18500, 0),
#  (2019, 'Malays', 'Male', '55 - 59 Years', 20465, 0),
#  (2019, 'Malays', 'Male', '60 - 64 Years', 16030, 0),
#  (2019, 'Malays', 'Male', '65 - 69 Years', 10509, 0),
#  (2019, 'Malays', 'Male', '70 - 74 Years', 5908, 0),
#  (2019, 'Malays', 'Male', '75 - 79 Years', 2968, 0),
#  (2019, 'Malays', 'Male', '80 - 84 Years', 2097, 0),
#  (2019, 'Malays', 'Male', '85 - 89 Years', 960, 0),
#  (2019, 'Malays', 'Male', '65 Years & Over', 22918, 0),
#  (2019, 'Malays', 'Male', '70 Years & Over', 12409, 0),
#  (2019, 'Malays', 'Male', '75 Years & Over', 6501, 0),
#  (2019, 'Malays', 'Male', '80 Years & Over', 3533, 0),
#  (2019, 'Malays', 'Male', '85 Years & Over', 1436, 0),
#  (2019, 'Malays', 'Male', '90 Years & Over', 476, 0),
#  (2019, 'Malays', 'Female', '0 - 4 Years', 18099, 1),
#  (2019, 'Malays', 'Female', '5 - 9 Years', 15053, 1),
#  (2019, 'Malays', 'Female', '10 - 14 Years', 15811, 1),
#  (2019, 'Malays', 'Female', '15 - 19 Years', 18521, 1),
#  (2019, 'Malays', 'Female', '20 - 24 Years', 21375, 1),
#  (2019, 'Malays', 'Female', '25 - 29 Years', 23658, 1),
#  (2019, 'Malays', 'Female', '30 - 34 Years', 20372, 1),
#  (2019, 'Malays', 'Female', '35 - 39 Years', 16515, 1),
#  (2019, 'Malays', 'Female', '40 - 44 Years', 13164, 1),
#  (2019, 'Malays', 'Female', '45 - 49 Years', 15023, 1),
#  (2019, 'Malays', 'Female', '50 - 54 Years', 19017, 1),
#  (2019, 'Malays', 'Female', '55 - 59 Years', 20462, 1),
#  (2019, 'Malays', 'Female', '60 - 64 Years', 16408, 1),
#  (2019, 'Malays', 'Female', '65 - 69 Years', 11556, 1),
#  (2019, 'Malays', 'Female', '70 - 74 Years', 6780, 1),
#  (2019, 'Malays', 'Female', '75 - 79 Years', 3885, 1),
#  (2019, 'Malays', 'Female', '80 - 84 Years', 2859, 1),
#  (2019, 'Malays', 'Female', '85 - 89 Years', 1602, 1),
#  (2019, 'Malays', 'Female', '65 Years & Over', 27347, 1),
#  (2019, 'Malays', 'Female', '70 Years & Over', 15791, 1),
#  (2019, 'Malays', 'Female', '75 Years & Over', 9011, 1),
#  (2019, 'Malays', 'Female', '80 Years & Over', 5126, 1),
#  (2019, 'Malays', 'Female', '85 Years & Over', 2267, 1),
#  (2019, 'Malays', 'Female', '90 Years & Over', 665, 1),
#  (2019, 'Chinese', 'Male', '0 - 4 Years', 60480, 0),
#  (2019, 'Chinese', 'Male', '5 - 9 Years', 65285, 0),
#  (2019, 'Chinese', 'Male', '10 - 14 Years', 65967, 0),
#  (2019, 'Chinese', 'Male', '15 - 19 Years', 72330, 0),
#  (2019, 'Chinese', 'Male', '20 - 24 Years', 84196, 0),
#  (2019, 'Chinese', 'Male', '25 - 29 Years', 91266, 0),
#  (2019, 'Chinese', 'Male', '30 - 34 Years', 85027, 0),
#  (2019, 'Chinese', 'Male', '35 - 39 Years', 84897, 0),
#  (2019, 'Chinese', 'Male', '40 - 44 Years', 86862, 0),
#  (2019, 'Chinese', 'Male', '45 - 49 Years', 95153, 0),
#  (2019, 'Chinese', 'Male', '50 - 54 Years', 96614, 0),
#  (2019, 'Chinese', 'Male', '55 - 59 Years', 106695, 0),
#  (2019, 'Chinese', 'Male', '60 - 64 Years', 103935, 0),
#  (2019, 'Chinese', 'Male', '65 - 69 Years', 85480, 0),
#  (2019, 'Chinese', 'Male', '70 - 74 Years', 57799, 0),
#  (2019, 'Chinese', 'Male', '75 - 79 Years', 35116, 0),
#  (2019, 'Chinese', 'Male', '80 - 84 Years', 21640, 0),
#  (2019, 'Chinese', 'Male', '85 - 89 Years', 10137, 0),
#  (2019, 'Chinese', 'Male', '65 Years & Over', 214627, 0),
#  (2019, 'Chinese', 'Male', '70 Years & Over', 129147, 0),
#  (2019, 'Chinese', 'Male', '75 Years & Over', 71348, 0),
#  (2019, 'Chinese', 'Male', '80 Years & Over', 36232, 0),
#  (2019, 'Chinese', 'Male', '85 Years & Over', 14592, 0),
#  (2019, 'Chinese', 'Male', '90 Years & Over', 4455, 0),
#  (2019, 'Chinese', 'Female', '0 - 4 Years', 57438, 1),
#  (2019, 'Chinese', 'Female', '5 - 9 Years', 61199, 1),
#  (2019, 'Chinese', 'Female', '10 - 14 Years', 62415, 1),
#  (2019, 'Chinese', 'Female', '15 - 19 Years', 67818, 1),
#  (2019, 'Chinese', 'Female', '20 - 24 Years', 78196, 1),
#  (2019, 'Chinese', 'Female', '25 - 29 Years', 84782, 1),
#  (2019, 'Chinese', 'Female', '30 - 34 Years', 81957, 1),
#  (2019, 'Chinese', 'Female', '35 - 39 Years', 86056, 1),
#  (2019, 'Chinese', 'Female', '40 - 44 Years', 92057, 1),
#  (2019, 'Chinese', 'Female', '45 - 49 Years', 101972, 1),
#  (2019, 'Chinese', 'Female', '50 - 54 Years', 100791, 1),
#  (2019, 'Chinese', 'Female', '55 - 59 Years', 108375, 1),
#  (2019, 'Chinese', 'Female', '60 - 64 Years', 107101, 1),
#  (2019, 'Chinese', 'Female', '65 - 69 Years', 89111, 1),
#  (2019, 'Chinese', 'Female', '70 - 74 Years', 64409, 1),
#  (2019, 'Chinese', 'Female', '75 - 79 Years', 43777, 1),
#  (2019, 'Chinese', 'Female', '80 - 84 Years', 29929, 1),
#  (2019, 'Chinese', 'Female', '85 - 89 Years', 18161, 1),
#  (2019, 'Chinese', 'Female', '65 Years & Over', 257498, 1),
#  (2019, 'Chinese', 'Female', '70 Years & Over', 168387, 1),
#  (2019, 'Chinese', 'Female', '75 Years & Over', 103978, 1),
#  (2019, 'Chinese', 'Female', '80 Years & Over', 60201, 1),
#  (2019, 'Chinese', 'Female', '85 Years & Over', 30272, 1),
#  (2019, 'Chinese', 'Female', '90 Years & Over', 12111, 1),
#  (2019, 'Indians', 'Male', '0 - 4 Years', 6533, 0),
#  (2019, 'Indians', 'Male', '5 - 9 Years', 6822, 0),
#  (2019, 'Indians', 'Male', '10 - 14 Years', 7989, 0),
#  (2019, 'Indians', 'Male', '15 - 19 Years', 9066, 0),
#  (2019, 'Indians', 'Male', '20 - 24 Years', 9911, 0),
#  (2019, 'Indians', 'Male', '25 - 29 Years', 10270, 0),
#  (2019, 'Indians', 'Male', '30 - 34 Years', 9235, 0),
#  (2019, 'Indians', 'Male', '35 - 39 Years', 8546, 0),
#  (2019, 'Indians', 'Male', '40 - 44 Years', 8074, 0),
#  (2019, 'Indians', 'Male', '45 - 49 Years', 9849, 0),
#  (2019, 'Indians', 'Male', '50 - 54 Years', 10927, 0),
#  (2019, 'Indians', 'Male', '55 - 59 Years', 10818, 0),
#  (2019, 'Indians', 'Male', '60 - 64 Years', 9032, 0),
#  (2019, 'Indians', 'Male', '65 - 69 Years', 6284, 0),
#  (2019, 'Indians', 'Male', '70 - 74 Years', 3710, 0),
#  (2019, 'Indians', 'Male', '75 - 79 Years', 1779, 0),
#  (2019, 'Indians', 'Male', '80 - 84 Years', 1173, 0),
#  (2019, 'Indians', 'Male', '85 - 89 Years', 870, 0),
#  (2019, 'Indians', 'Male', '65 Years & Over', 14456, 0),
#  (2019, 'Indians', 'Male', '70 Years & Over', 8172, 0),
#  (2019, 'Indians', 'Male', '75 Years & Over', 4462, 0),
#  (2019, 'Indians', 'Male', '80 Years & Over', 2683, 0),
#  (2019, 'Indians', 'Male', '85 Years & Over', 1510, 0),
#  (2019, 'Indians', 'Male', '90 Years & Over', 640, 0),
#  (2019, 'Indians', 'Female', '0 - 4 Years', 6235, 1),
#  (2019, 'Indians', 'Female', '5 - 9 Years', 6667, 1),
#  (2019, 'Indians', 'Female', '10 - 14 Years', 7883, 1),
#  (2019, 'Indians', 'Female', '15 - 19 Years', 8709, 1),
#  (2019, 'Indians', 'Female', '20 - 24 Years', 9373, 1),
#  (2019, 'Indians', 'Female', '25 - 29 Years', 9993, 1),
#  (2019, 'Indians', 'Female', '30 - 34 Years', 8922, 1),
#  (2019, 'Indians', 'Female', '35 - 39 Years', 8465, 1),
#  (2019, 'Indians', 'Female', '40 - 44 Years', 8124, 1),
#  (2019, 'Indians', 'Female', '45 - 49 Years', 9120, 1),
#  (2019, 'Indians', 'Female', '50 - 54 Years', 9766, 1),
#  (2019, 'Indians', 'Female', '55 - 59 Years', 10518, 1),
#  (2019, 'Indians', 'Female', '60 - 64 Years', 8931, 1),
#  (2019, 'Indians', 'Female', '65 - 69 Years', 6788, 1),
#  (2019, 'Indians', 'Female', '70 - 74 Years', 4468, 1),
#  (2019, 'Indians', 'Female', '75 - 79 Years', 2571, 1),
#  (2019, 'Indians', 'Female', '80 - 84 Years', 1908, 1),
#  (2019, 'Indians', 'Female', '85 - 89 Years', 978, 1),
#  (2019, 'Indians', 'Female', '65 Years & Over', 17142, 1),
#  (2019, 'Indians', 'Female', '70 Years & Over', 10354, 1),
#  (2019, 'Indians', 'Female', '75 Years & Over', 5886, 1),
#  (2019, 'Indians', 'Female', '80 Years & Over', 3315, 1),
#  (2019, 'Indians', 'Female', '85 Years & Over', 1407, 1),
#  (2019, 'Indians', 'Female', '90 Years & Over', 429, 1),
#  (2019, 'Other Ethnic Groups', 'Male', '0 - 4 Years', 2596, 0),
#  (2019, 'Other Ethnic Groups', 'Male', '5 - 9 Years', 2572, 0),
#  (2019, 'Other Ethnic Groups', 'Male', '10 - 14 Years', 2319, 0),
#  (2019, 'Other Ethnic Groups', 'Male', '15 - 19 Years', 2123, 0),
#  (2019, 'Other Ethnic Groups', 'Male', '20 - 24 Years', 2083, 0),
#  (2019, 'Other Ethnic Groups', 'Male', '25 - 29 Years', 1962, 0),
#  (2019, 'Other Ethnic Groups', 'Male', '30 - 34 Years', 1541, 0),
#  (2019, 'Other Ethnic Groups', 'Male', '35 - 39 Years', 1290, 0),
#  (2019, 'Other Ethnic Groups', 'Male', '40 - 44 Years', 1301, 0),
#  (2019, 'Other Ethnic Groups', 'Male', '45 - 49 Years', 1567, 0),
#  (2019, 'Other Ethnic Groups', 'Male', '50 - 54 Years', 1469, 0),
#  (2019, 'Other Ethnic Groups', 'Male', '55 - 59 Years', 1441, 0),
#  (2019, 'Other Ethnic Groups', 'Male', '60 - 64 Years', 1178, 0),
#  (2019, 'Other Ethnic Groups', 'Male', '65 - 69 Years', 920, 0),
#  (2019, 'Other Ethnic Groups', 'Male', '70 - 74 Years', 618, 0),
#  (2019, 'Other Ethnic Groups', 'Male', '75 - 79 Years', 302, 0),
#  (2019, 'Other Ethnic Groups', 'Male', '80 - 84 Years', 227, 0),
#  (2019, 'Other Ethnic Groups', 'Male', '85 - 89 Years', 165, 0),
#  (2019, 'Other Ethnic Groups', 'Male', '65 Years & Over', 2316, 0),
#  (2019, 'Other Ethnic Groups', 'Male', '70 Years & Over', 1396, 0),
#  (2019, 'Other Ethnic Groups', 'Male', '75 Years & Over', 778, 0),
#  (2019, 'Other Ethnic Groups', 'Male', '80 Years & Over', 476, 0),
#  (2019, 'Other Ethnic Groups', 'Male', '85 Years & Over', 249, 0),
#  (2019, 'Other Ethnic Groups', 'Male', '90 Years & Over', 84, 0),
#  (2019, 'Other Ethnic Groups', 'Female', '0 - 4 Years', 2566, 1),
#  (2019, 'Other Ethnic Groups', 'Female', '5 - 9 Years', 2658, 1),
#  (2019, 'Other Ethnic Groups', 'Female', '10 - 14 Years', 2356, 1),
#  (2019, 'Other Ethnic Groups', 'Female', '15 - 19 Years', 2087, 1),
#  (2019, 'Other Ethnic Groups', 'Female', '20 - 24 Years', 1874, 1),
#  (2019, 'Other Ethnic Groups', 'Female', '25 - 29 Years', 1607, 1),
#  (2019, 'Other Ethnic Groups', 'Female', '30 - 34 Years', 1801, 1),
#  (2019, 'Other Ethnic Groups', 'Female', '35 - 39 Years', 1858, 1),
#  (2019, 'Other Ethnic Groups', 'Female', '40 - 44 Years', 1697, 1),
#  (2019, 'Other Ethnic Groups', 'Female', '45 - 49 Years', 1828, 1),
#  (2019, 'Other Ethnic Groups', 'Female', '50 - 54 Years', 1779, 1),
#  (2019, 'Other Ethnic Groups', 'Female', '55 - 59 Years', 1605, 1),
#  (2019, 'Other Ethnic Groups', 'Female', '60 - 64 Years', 1284, 1),
#  (2019, 'Other Ethnic Groups', 'Female', '65 - 69 Years', 881, 1),
#  (2019, 'Other Ethnic Groups', 'Female', '70 - 74 Years', 637, 1),
#  (2019, 'Other Ethnic Groups', 'Female', '75 - 79 Years', 394, 1),
#  (2019, 'Other Ethnic Groups', 'Female', '80 - 84 Years', 357, 1),
#  (2019, 'Other Ethnic Groups', 'Female', '85 - 89 Years', 247, 1),
#  (2019, 'Other Ethnic Groups', 'Female', '65 Years & Over', 2700, 1),
#  (2019, 'Other Ethnic Groups', 'Female', '70 Years & Over', 1819, 1),
#  (2019, 'Other Ethnic Groups', 'Female', '75 Years & Over', 1182, 1),
#  (2019, 'Other Ethnic Groups', 'Female', '80 Years & Over', 788, 1),
#  (2019, 'Other Ethnic Groups', 'Female', '85 Years & Over', 431, 1),
#  (2019, 'Other Ethnic Groups', 'Female', '90 Years & Over', 184, 1),
#  (2018, 'All ethnicity', 'Male', '0 - 4 Years', 88607, 0),
#  (2018, 'All ethnicity', 'Male', '5 - 9 Years', 90485, 0),
#  (2018, 'All ethnicity', 'Male', '10 - 14 Years', 92319, 0),
#  (2018, 'All ethnicity', 'Male', '15 - 19 Years', 106330, 0),
#  (2018, 'All ethnicity', 'Male', '20 - 24 Years', 122575, 0),
#  (2018, 'All ethnicity', 'Male', '25 - 29 Years', 129837, 0),
#  (2018, 'All ethnicity', 'Male', '30 - 34 Years', 110705, 0),
#  (2018, 'All ethnicity', 'Male', '35 - 39 Years', 111745, 0),
#  (2018, 'All ethnicity', 'Male', '40 - 44 Years', 111210, 0),
#  (2018, 'All ethnicity', 'Male', '45 - 49 Years', 120509, 0),
#  (2018, 'All ethnicity', 'Male', '50 - 54 Years', 132636, 0),
#  (2018, 'All ethnicity', 'Male', '55 - 59 Years', 139669, 0),
#  (2018, 'All ethnicity', 'Male', '60 - 64 Years', 127127, 0),
#  (2018, 'All ethnicity', 'Male', '65 - 69 Years', 98644, 0),
#  (2018, 'All ethnicity', 'Male', '70 - 74 Years', 60956, 0),
#  (2018, 'All ethnicity', 'Male', '75 - 79 Years', 39346, 0),
#  (2018, 'All ethnicity', 'Male', '80 - 84 Years', 22952, 0),
#  (2018, 'All ethnicity', 'Male', '85 - 89 Years', 11429, 0),
#  (2018, 'All ethnicity', 'Male', '65 Years & Over', 238434, 0),
#  (2018, 'All ethnicity', 'Male', '70 Years & Over', 139790, 0),
#  (2018, 'All ethnicity', 'Male', '75 Years & Over', 78834, 0),
#  (2018, 'All ethnicity', 'Male', '80 Years & Over', 39488, 0),
#  (2018, 'All ethnicity', 'Male', '85 Years & Over', 16536, 0),
#  (2018, 'All ethnicity', 'Male', '90 Years & Over', 5107, 0),
#  (2018, 'All ethnicity', 'Female', '0 - 4 Years', 84014, 1),
#  (2018, 'All ethnicity', 'Female', '5 - 9 Years', 85311, 1),
#  (2018, 'All ethnicity', 'Female', '10 - 14 Years', 87903, 1),
#  (2018, 'All ethnicity', 'Female', '15 - 19 Years', 99393, 1),
#  (2018, 'All ethnicity', 'Female', '20 - 24 Years', 114471, 1),
#  (2018, 'All ethnicity', 'Female', '25 - 29 Years', 121121, 1),
#  (2018, 'All ethnicity', 'Female', '30 - 34 Years', 107169, 1),
#  (2018, 'All ethnicity', 'Female', '35 - 39 Years', 112880, 1),
#  (2018, 'All ethnicity', 'Female', '40 - 44 Years', 116346, 1),
#  (2018, 'All ethnicity', 'Female', '45 - 49 Years', 126820, 1),
#  (2018, 'All ethnicity', 'Female', '50 - 54 Years', 135209, 1),
#  (2018, 'All ethnicity', 'Female', '55 - 59 Years', 140727, 1),
#  (2018, 'All ethnicity', 'Female', '60 - 64 Years', 130421, 1),
#  (2018, 'All ethnicity', 'Female', '65 - 69 Years', 104261, 1),
#  (2018, 'All ethnicity', 'Female', '70 - 74 Years', 69099, 1),
#  (2018, 'All ethnicity', 'Female', '75 - 79 Years', 50190, 1),
#  ...]

# %% [markdown]
# ### g. Rename the table:
# ```sql
# ALTER TABLE copy_pop
# RENAME TO new_name
# ```

# %%
# %%sql
# ALTER TABLE copy_pop
# RENAME TO population_official
# Out:
#  * sqlite:///testdatabase.db
# Done.
# []

# %% [markdown]
# ### h. Find the average number associated with  each value within a category:
# ```sql
# SELECT AVG(VALUES)
# FROM table
# GROUP BY category_col
# ```
# - Find the average of all age-groups for each ethnic_groups in 2021.

# %%
# %%sql
# SELECT ETHNIC_GROUP, GENDER, AVG(VALUE) AS AVG_VALUE_2021
# FROM population_official
# WHERE YEAR = 2021
# GROUP BY ETHNIC_GROUP, GENDER;
# Out:
#  * sqlite:///testdatabase.db
# Done.
# [('All ethnicity', 'Female', 106816.54166666667),
#  ('All ethnicity', 'Male', 97713.54166666667),
#  ('Chinese', 'Female', 84585.875),
#  ('Chinese', 'Male', 76186.79166666667),
#  ('Indians', 'Female', 7082.375),
#  ('Indians', 'Male', 6873.833333333333),
#  ('Malays', 'Female', 13667.708333333334),
#  ('Malays', 'Male', 13312.125),
#  ('Other Ethnic Groups', 'Female', 1480.5833333333333),
#  ('Other Ethnic Groups', 'Male', 1340.7916666666667)]

# %% [markdown]
# - Sort the table:
#     - By the order of the ethnic_groups
#     - By the order of gender: female -> male

# %%
# %%sql
# SELECT ETHNIC_GROUP, GENDER, AVG(VALUE) AS AVG_VALUE_2021
# FROM population_official
# WHERE YEAR = 2021
# GROUP BY ETHNIC_GROUP, GENDER
# ORDER BY ETHNIC_GROUP DESC, GENDER ASC;
# Out:
#  * sqlite:///testdatabase.db
# Done.
# [('Other Ethnic Groups', 'Female', 1480.5833333333333),
#  ('Other Ethnic Groups', 'Male', 1340.7916666666667),
#  ('Malays', 'Female', 13667.708333333334),
#  ('Malays', 'Male', 13312.125),
#  ('Indians', 'Female', 7082.375),
#  ('Indians', 'Male', 6873.833333333333),
#  ('Chinese', 'Female', 84585.875),
#  ('Chinese', 'Male', 76186.79166666667),
#  ('All ethnicity', 'Female', 106816.54166666667),
#  ('All ethnicity', 'Male', 97713.54166666667)]

# %% [markdown]
# ### i. Filter output:
# - Find the average of all age groups for each gender of each ethnic group in 2021. Show only groups that have an average above 10000.
# - Sort the table:
#     - By the order of the ethnic_groups
#     - By the order of gender: female -> male
# => Use `HAVING`
# - HAVING vs WHERE:
#     - WHERE: states the condition of INPUT
#     - HAVING: states the condition of OUTPUT

# %% [markdown]
# ### j. Logical operators:
#     - `>` : bigger than
#     - `<` : smaller than
#     - `>=`: bigger than or equal
#     - `<=`: smaller than or equal
#     - `BETWEEN X AND Y`: >=X and <=Y

# %%
# %%sql
# SELECT ETHNIC_GROUP, GENDER, AVG(VALUE) AS AVG_VALUE_2021_above10000
# FROM population_official
# WHERE YEAR = 2021
# GROUP BY ETHNIC_GROUP, GENDER
# HAVING AVG(VALUE) >10000
# ORDER BY ETHNIC_GROUP DESC, GENDER ASC;
# Out:
#  * sqlite:///testdatabase.db
# Done.
# [('Malays', 'Female', 13667.708333333334),
#  ('Malays', 'Male', 13312.125),
#  ('Chinese', 'Female', 84585.875),
#  ('Chinese', 'Male', 76186.79166666667),
#  ('All ethnicity', 'Female', 106816.54166666667),
#  ('All ethnicity', 'Male', 97713.54166666667)]

# %% [markdown]
# - Find the average of all age groups for each gender of each ethnic group in 2021. Show only groups that have an average >=10000 and <=90000
# - Sort the table:
#     - By the order of the ethnic_groups
#     - By the order of gender: female -> male

# %%
# %%sql
# SELECT GENDER, ETHNIC_GROUP, AVG(VALUE) AS average_2021above
# FROM population_official
# WHERE YEAR = 2021
# GROUP BY ETHNIC_GROUP, GENDER
# HAVING AVG(VALUE) BETWEEN 10000 AND 90000
# ORDER BY ETHNIC_GROUP DESC, GENDER ASC
# Out:
#  * sqlite:///testdatabase.db
# Done.
# [('Female', 'Malays', 13667.708333333334),
#  ('Male', 'Malays', 13312.125),
#  ('Female', 'Chinese', 84585.875),
#  ('Male', 'Chinese', 76186.79166666667)]

# %% [markdown]
# ### k. Truncate the table: remove all the rows of the table
# ```sql
# TRUNCATE TABLE table_name;
# ```
# - TRUNCATE vs DELETE:
#     - TRUNCATE:
#         - Is a DDL statement
#         - Faster
#         - Remove all rows, cannot be integrated with criteria
#     - DELETE:
#         - Is a DML statement
#         - Slower
#         - Allow users to integrate with criteria

# %% [markdown]
# ### l. Drop the table: remove the whole table itself
# ```sql
# DROP TABLE table_name;
# ```
# - DROP vs TRUNCATE:
#     - DROP: Remove the WHOLE table
#     - TRUNCATE: Remove rows only, still keeps columns
